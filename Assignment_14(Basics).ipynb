# %% [markdown]
# Q_(1):- What does RGBA stand for?
# Sol_1:- RGBA stands for Red, Green, Blue and Alpha in color.

# %% [markdown]
# Q_(2):- From the Pillow module, how do you get the RGBA value of any images?
# Sol_2:- To get the RGBA value of any image we need to import Image from PIL module, then convert into RGBA image and call getdata().It will give all the rgba value of that image.
# for example:-

# %%
from PIL import Image
r = Image.open('hi1.jpg')
rb = r.convert("RGBA")
list(rb.getdata())
# Out:
# [(3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (3, 10, 38, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (4, 11, 40, 255),
#  (4, 11, 40, 255),
#  (4, 11, 40, 255),
#  (4, 11, 40, 255),
#  (4, 11, 40, 255),
#  (4, 11, 40, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (5, 12, 41, 255),
#  (6, 11, 41, 255),
#  (6, 11, 41, 255),
#  (6, 11, 41, 255),
#  (6, 11, 41, 255),
#  (6, 11, 41, 255),
#  (6, 11, 40, 255),
#  (6, 11, 40, 255),
#  (6, 11, 40, 255),
#  (5, 10, 39, 255),
#  (5, 10, 39, 255),
#  (5, 10, 39, 255),
#  (4, 10, 36, 255),
#  (4, 10, 36, 255),
#  (4, 10, 36, 255),
#  (4, 10, 36, 255),
# ...

# %% [markdown]
# Q_(3):- What is a box tuple, and how does it work?
# Sol_3:- The box tuple is an argument taken by pillow function. This box tuple is a tuple of four integer coordinates that represent a rectangular region in an image. The four integers are:
#
# Left- The x-coordinate of the leftmost edge of the box.
#
# Top- The y-coordinate of the top edge of the box.
#
# Right- The x-coordinate of one pixel to the right of the rightmost edge
# of the box. This integer must be greater than the left integer.
#
# Bottom- The y-coordinate of one pixel lower than the bottom edge of
# the box. This integer must be greater than the top integ

# %% [markdown]
# Q_(4):- Use your image and load in notebook then, How can you find out the width and height of an Image object?
# Sol_4:-

# %%
from PIL import Image
im = Image.open('hi1.jpg')
width, height = im.size          # width and height of an image object which is im

# %%
width
# Out:
# 2048

# %%
height
# Out:
# 1152

# %% [markdown]
# Q_(5):- What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# Sol_5:- imageobje.crop((0,50,50,50))

# %% [markdown]
# Q_(6):- After making changes to an Image object, how could you save it as an image file?
# Sol_6:- By using imgobj.save('newfilename.ext_name').

# %% [markdown]
# Q_(7):-  What module contains Pillow’s shape-drawing code?
# Sol_7:- ImageDraw module contains Pillow’s shape-drawing code.

# %% [markdown]
# Q_(8):- Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# Sol_8:- ImageDraw have shape drawing methods such as line(), point(), rectangle(). To get this kind of object by passing image object to this ImageDraw.Draw() function.
