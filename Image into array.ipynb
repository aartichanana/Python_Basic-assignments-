# %%
# Import libraries
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Open image by using its location
img = Image.open(b"C:\Users\LENOVO\Desktop\Data/Dssheet.jpg")

# %%
#img.show()                 this open photo viewer

# %%
#Display image
plt.imshow(img)

# %%
#Properties of an image
print(img.size)
print(img.format)
print(img.mode)
# Out:
# (800, 789)
# JPEG
# RGB

# %%
# Convert image into an array
new_img = np.array(img)

# %%
new_img
# Out:
# array([[[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]],
#
#        [[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]],
#
#        [[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]],
#
#        ...,
#
#        [[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]],
#
#        [[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]],
#
#        [[0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0],
#         ...,
#         [0, 4, 0],
#         [0, 4, 0],
#         [0, 4, 0]]], dtype=uint8)

# %%
# Convert back into original image
Org_img = Image.fromarray(new_img)
plt.imshow(Org_img)
